# %%
# Import all the stuff
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in all the data
nfl = pd.read_csv('2016PlayByPlay.csv')
nfl.set_index('Unnamed: 0', inplace=True)
nfl
# Out:
# c:\users\mughi\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (26,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   Date      GameID  Drive  qtr  down   time  TimeUnder  \
# Unnamed: 0
# 1           2016-09-08  2016090800      1    1   NaN  15:00         15
# 2           2016-09-08  2016090800      1    1   1.0  15:00         15
# 3           2016-09-08  2016090800      1    1   1.0  14:17         15
# 4           2016-09-08  2016090800      1    1   2.0  14:13         15
# 5           2016-09-08  2016090800      1    1   3.0  14:08         15
# 6           2016-09-08  2016090800      1    1   1.0  13:42         14
# 7           2016-09-08  2016090800      1    1   2.0  13:01         14
# 8           2016-09-08  2016090800      1    1   1.0  12:23         13
# ...

# %%
nfl.dtypes
# Out:
# Unnamed: 0             int64
# Date                  object
# GameID                 int64
# Drive                  int64
# qtr                    int64
# down                 float64
# time                  object
# TimeUnder              int64
# TimeSecs             float64
# PlayTimeDiff         float64
# SideofField           object
# yrdln                float64
# yrdline100           float64
# ydstogo                int64
# ydsnet                 int64
# GoalToGo             float64
# FirstDown            float64
# posteam               object
# DefensiveTeam         object
# desc                  object
# PlayAttempted          int64
# Yards.Gained           int64
# sp                     int64
# Touchdown              int64
# ExPointResult         object
# TwoPointConv          object
# DefTwoPoint           object
# Safety                 int64
# Onsidekick             int64
# PuntResult            object
#                       ...
# Tackler2              object
# ...

# %%
nfl.iloc[:, 46]
# Out:
# Unnamed: 0
# 1                  NaN
# 2            L.Kuechly
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6            R.McClain
# 7          J.Bradberry
# 8            R.McClain
# 9            C.Johnson
# 10          B.Marshall
# 11             T.Davis
# 12              D.Ware
# 13                 NaN
# 14                 NaN
# 15           J.Simmons
# 16           D.Stewart
# 17               S.Ray
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23             K.Short
# 24         J.Bradberry
# 25           L.Kuechly
# 26             T.Davis
# 27         J.Bradberry
# 28             T.Davis
# 29         J.Bradberry
# 30           L.Kuechly
#              ...
# 45707         T.Wilson
# 45708         T.Walker
# 45709              NaN
# 45710           D.Slay
# 45711              NaN
# 45712         T.Wilson
# 45713              NaN
# 45714              NaN
# ...
